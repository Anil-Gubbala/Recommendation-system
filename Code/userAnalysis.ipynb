# %%
# %%capture capt
# %run merger.ipynb

# %%
plt.hist(ratings["rating"],)
# Out:
# (array([ 1101.,  3326.,  1687.,  7271.,  4449., 20064., 10538., 28750.,
#          7723., 15095.]),
#  array([0.5 , 0.95, 1.4 , 1.85, 2.3 , 2.75, 3.2 , 3.65, 4.1 , 4.55, 5.  ]),
#  <BarContainer object of 10 artists>)

# %%
movieRatings['userId']
# Out:
# 0         15
# 1         26
# 2         31
# 3         48
# 4         72
#         ...
# 66942    460
# 66943    580
# 66944    596
# 66945    624
# 66946    648
# Name: userId, Length: 66947, dtype: int64

# %%
a = movieRatings[(movieRatings["userId"]== 20) & (movieRatings["rating"] > 4)]
a.iloc[:]
# Out:
#        tmdbId                            title  popularity  vote_average  \
# 8939      607                     Men in Black  104.121555           6.9
# 12901     602                 Independence Day   60.442593           6.7
# 15799     603                       The Matrix  104.309993           7.9
# 25499    5503                     The Fugitive   54.884297           7.2
# 33900     533     The Curse of the Were-Rabbit   30.380747           6.8
# 38128     278         The Shawshank Redemption  136.747729           8.5
# 40689      85          Raiders of the Lost Ark   68.159596           7.7
# 47412     947               Lawrence of Arabia   41.286336           7.8
# 52498   24137                 An Ideal Husband    4.519523           6.3
# 55559   11971           Much Ado About Nothing   10.193770           7.2
# 58121   10215                    Sliding Doors   15.639016           6.5
# 60234    1088                      Whale Rider   12.439495           7.1
# ...

# %%
a = sortRatings[::-1][:10]

# %%
b = pd.DataFrame(a)
b
# Out:
#         rating
# tmdbId
# 347969    2674
# 342521    3335
# 334074    3361
# 333371    3358
# 332567     147
# 332411    2167
# 329833    2200
# 328425    1150
# 328111    2177
# 325173    2730
