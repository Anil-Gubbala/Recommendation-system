# %%
# !pip install ipynb
from ipynb.fs.full.preprocessing import *

# %%
links.head(2)
# Out:
#    movieId  imdbId  tmdbId
# 0        1  114709   862.0
# 1        2  113497  8844.0

# %%
movies.head(2)
# Out:
#    tmdbId                                           keywords  \
# 0   19995  [{"id": 1463, "name": "culture clash"}, {"id":...
# 1     285  [{"id": 270, "name": "ocean"}, {"id": 726, "na...
#
#                                       title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
#
#    vote_average  vote_count                                         genres  \
# 0           7.2       11800  [Action, Adventure, Fantasy, Science Fiction]
# 1           6.9        4500                   [Adventure, Fantasy, Action]
#
#                                                 cast         directors
# 0  [Sam Worthington, Zoe Saldana, Sigourney Weave...   [James Cameron]
# 1  [Johnny Depp, Orlando Bloom, Keira Knightley, ...  [Gore Verbinski]

# %%
movieRatings = movies.merge(links,on='tmdbId')
movieRatings.head(2)
# Out:
#    tmdbId                                           keywords  \
# 0   19995  [{"id": 1463, "name": "culture clash"}, {"id":...
# 1     285  [{"id": 270, "name": "ocean"}, {"id": 726, "na...
#
#                                       title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
#
#    vote_average  vote_count                                         genres  \
# 0           7.2       11800  [Action, Adventure, Fantasy, Science Fiction]
# 1           6.9        4500                   [Adventure, Fantasy, Action]
#
#                                                 cast         directors  \
# 0  [Sam Worthington, Zoe Saldana, Sigourney Weave...   [James Cameron]
# ...

# %%
movieRatings = movieRatings.merge(ratings,on='movieId')
movieRatings.head(2)
# Out:
#    tmdbId                                           keywords   title  \
# 0   19995  [{"id": 1463, "name": "culture clash"}, {"id":...  Avatar
# 1   19995  [{"id": 1463, "name": "culture clash"}, {"id":...  Avatar
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  In the 22nd century, a paraplegic Marine is di...  150.437577
#
#    vote_average  vote_count                                         genres  \
# 0           7.2       11800  [Action, Adventure, Fantasy, Science Fiction]
# 1           7.2       11800  [Action, Adventure, Fantasy, Science Fiction]
#
#                                                 cast        directors  \
# 0  [Sam Worthington, Zoe Saldana, Sigourney Weave...  [James Cameron]
# 1  [Sam Worthington, Zoe Saldana, Sigourney Weave...  [James Cameron]
#
#    movieId  imdbId  userId  rating   timestamp
# 0    72998  499549      15     4.0  1261944230
# ...

# %%
movieRatings = movieRatings.drop(columns=['keywords','overview','genres','cast','directors'],errors='ignore')
movieRatings
# Out:
#        tmdbId        title  popularity  vote_average  vote_count  movieId  \
# 0       19995       Avatar  150.437577           7.2       11800    72998
# 1       19995       Avatar  150.437577           7.2       11800    72998
# 2       19995       Avatar  150.437577           7.2       11800    72998
# 3       19995       Avatar  150.437577           7.2       11800    72998
# 4       19995       Avatar  150.437577           7.2       11800    72998
# ...       ...          ...         ...           ...         ...      ...
# 66942    9367  El Mariachi   14.269792           6.6         238     3267
# 66943    9367  El Mariachi   14.269792           6.6         238     3267
# 66944    9367  El Mariachi   14.269792           6.6         238     3267
# 66945    9367  El Mariachi   14.269792           6.6         238     3267
# 66946    9367  El Mariachi   14.269792           6.6         238     3267
#
#        imdbId  userId  rating   timestamp
# ...

# %%
movieRatings.isna().sum()
# Out:
# tmdbId          0
# title           0
# popularity      0
# vote_average    0
# vote_count      0
# movieId         0
# imdbId          0
# userId          0
# rating          0
# timestamp       0
# dtype: int64

# %%
len(movies.tmdbId.unique())
# Out:
# 4803

# %%
len(movieRatings.movieId.unique())
# Out:
# 3394

# %%
len(ratings.movieId.unique())
# Out:
# 9066
